# %% [markdown]
# ## Studi Kasus : Visualiasi Data Pasien Penyakit Jantung

# %% [markdown]
# Ananda Aulia Rizky (DSF B)
# IT Telkom Purwokerto

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#Untuk mengarahkan ke gambar statis plot
# %matplotlib inline

# %%
df = pd.read_csv ('heart.csv') # load data
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ### Dataset berisi fitur berikut:
#    1. age     : (dalam tahun)
#    2. sex     : (1 = laki-laki; 0 = perempuan)
#    3. cp      : jenis nyeri dada
#    4. trestbps: tekanan darah istirahat (dalam mm Hg saat masuk rumah sakit)
#    5. chol    : kolestoral serum dalam mg/dl
#    6. fbs     : (gula darah puasa > 120 mg/dl) (1 = benar; 0 = salah)
#    7. restecg : hasil elektrokardiografi istirahat
#    8. thalach : detak jantung maksimum tercapai
#    9. exang   : angina yang diinduksi olahraga (1 = ya; 0 = tidak)
#    10. oldpeak: depresi ST yang disebabkan oleh olahraga relatif terhadap istirahat
#    11. slope  : kemiringan segmen ST latihan puncak
#    12. ca     : jumlah pembuluh utama (0-3) yang diwarnai oleh flourosopy
#    13. thal   : 3 = biasa; 6 = cacat tetap; 7 = cacat reversibel
#    14. target : 1 atau 0

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
cols = df.keys()

# %%
#pie chart
male =len(df[df['sex'] == 1])
female = len(df[df['sex']== 0])

plt.figure(figsize=(8,6))

# Data to plot
labels = 'Male','Female'
sizes = [male,female]
colors = ['yellowgreen', 'skyblue']
explode = (0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('Percentages of Sex', y=1.12, size=20) 
plt.axis('equal')
plt.show()

# %%
# Plot Line
sns.barplot(x = 'sex',
            y = 'age',
            data = df)
 
# Show the plot
plt.show()

# %%
# Plot Bar
sns.catplot(x="sex", y="thalach", hue = "cp", kind = "bar", data=df)

# %%
# Plot Scatter
sns.relplot(x="thalach", y="age", data = df)

# %%
sns.catplot(x="sex", y="age", kind = "swarm", data=df)

# %%
# Box
sns.catplot(x="sex", y="age", kind = "box", data=df)

# %%
# Pointplot 
sns.catplot(x="cp", y="chol", hue = "sex", kind = "point", data=df)

# %%
# Histogram
sns.distplot(df.exang)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='exang', ylabel='Density'>

# %%
sns.distplot(df.oldpeak, kde=False, rug = True)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='oldpeak'>

# %%
sns.jointplot(x="fbs", y="trestbps", data=df);

# %%
# Hexplot 
sns.jointplot(x=df.trestbps, y=df.oldpeak, kind="hex", data = df)

# %%
sns.jointplot(x="cp", y="thalach", data=df, kind="kde");

# %%
#Heatmaps
corrmat = df.corr()
f, ax = plt.subplots(figsize=(14, 8))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %%
# Boxen Plot
sns.catplot(x="age", y="chol", data=df, kind="boxen",height=4, aspect=2.7, hue = "sex")

# %%
# Ridge Plot
# Initialize the FacetGrid object
g = sns.FacetGrid(df, row="age", hue="cp", aspect=5, height=3)

# # Draw the densities in a few steps
g.map(sns.kdeplot, "sex", shade=True, alpha=1, lw=3.5, bw=.2)
g.map(sns.kdeplot, "sex", color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2)

# # Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color=color, ha="left", va="center", transform=ax.transAxes)
g.map(label, "sex")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.20)

# # Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Group berdasarkan Umur
df_age = df.groupby('cp')['age'].mean()
df_age
# Out:
# cp
# 0    55.692308
# 1    51.360000
# 2    53.517241
# 3    55.869565
# Name: age, dtype: float64

# %%
df_age.plot()
# Out:
# <AxesSubplot:xlabel='cp'>

# %%
df1=df.groupby('age')['chol'].sum().to_frame().reset_index()

# Membuat grafik bar
plt.barh(df1['age'],df1['chol'],color = ['#E6E6FA','#B0E0E6','#F0F8FF']) 

# Menambahkan Informasi
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title') 

#Tampilkan Plot
plt.show()

# %%
sns.set_context("paper", font_scale=3, rc={"font.size":8,"axes.labelsize":5})
# Construct iris plot
sns.swarmplot(x="cp", y="thal", data=df)

# Show plot
plt.show()
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Tentukan kolom chart
sns.barplot(x = 'sex',y = 'age',data = df,palette = "summer")
#membuat Legend
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title') 
# Tampilkan chart
plt.show()
