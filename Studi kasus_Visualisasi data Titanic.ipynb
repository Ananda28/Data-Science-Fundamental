# %% [markdown]
# # Visualiasi pada data Titanic

# %% [markdown]
# Ananda Aulia Rizky (DSF B)
# IT Telkom Purwokerto

# %%
import matplotlib.pyplot as plt
import numpy as np
#Untuk mengarahkan ke gambar statis plot
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic') # load data
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Plot Line
sns.barplot(x = 'who',
            y = 'age',
            data = df)
 
# Show the plot
plt.show()

# %%
# Plot Bar
sns.catplot(x="who", y="age", hue = "class", kind = "bar", data=df)

# %%
g = sns.factorplot("class", "survived", "sex", data=df, kind="bar", palette="muted", legend=False)               
# Show plot
plt.show()
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Plot Scatter
sns.relplot(x="fare", y="age", data = df)

# %%
sns.catplot(x="who", y="age", kind = "swarm", data=df)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.relplot(x="who", y="age", hue = "class", data = df)

# %%
sns.relplot(x="who", y="age", hue = "survived", data = df)

# %%
# Box
sns.catplot(x="who", y="age", kind = "box", data=df)

# %%
sns.catplot(x="who", y="age", hue = "survived", kind = "box", data=df)

# %%
sns.catplot(x="who", y="age", hue = "class", kind = "box", data=df)

# %%
# Tampilkan grafik penumpang berdasarkan sex
sns.catplot(x="who", y="age", hue = "sex", kind = "bar", data=df)

# %%
# Pointplot 
sns.catplot(x="who", y="age", hue = "sex", kind = "point", data=df)

# %%
sns.catplot(x="who", y="age", hue="sex",
            col="survived", aspect=.9,
            kind="swarm", data=df);
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Swarm plot
sns.catplot(x="who", y="age", hue="sex",
            col="class", aspect=.9,
            kind="swarm", data=df);
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Memvisualisasikan Distribusi Kumpulan Data

# %%
# Histogram
sns.distplot(df.fare)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.distplot(df.fare, kde=False, rug = True)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare'>

# %%
sns.jointplot(x="who", y="fare", data=df);

# %%
sns.jointplot(x="who", y="age", data=df);

# %%
# Hexplot 
sns.jointplot(x=df.fare, y=df.age, kind="hex", data = df)

# %%
sns.jointplot(x="fare", y="age", data=df, kind="kde");

# %%
#Heatmaps
corrmat = df.corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(corrmat, vmax=.7, square=True)
# Out:
# <AxesSubplot:>

# %%
#Kita bisa gunakan argumen annot=True untuk menampilkan korelasi antar atribut. 
#Jika nilai korelasi mendekati 1 maka hubungan antar atribut semakin tinggi
sns.heatmap(corrmat, vmax=.7, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corrmat, vmax=.7, annot=True, cmap='RdYlBu')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corrmat, vmax=.7, annot=True, cmap='magma')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corrmat, vmax=.7, annot=True, cmap='Purples')
# Out:
# <AxesSubplot:>

# %%
warna=sns.light_palette("blue")
sns.heatmap(corrmat, vmax=.7, annot=True, cmap=warna)
# Out:
# <AxesSubplot:>

# %%
# Boxen Plot
sns.catplot(x="fare", y="age", data=df, kind="boxen",height=4, aspect=2.7, hue = "who")

# %%
# Ridge Plot
# Initialize the FacetGrid object
g = sns.FacetGrid(df, row="who", hue="class", aspect=5, height=3)

# # Draw the densities in a few steps
g.map(sns.kdeplot, "age", shade=True, alpha=1, lw=3.5, bw=.2)
g.map(sns.kdeplot, "age", color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2)

# # Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color=color, ha="left", va="center", transform=ax.transAxes)
g.map(label, "age")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# # Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Group berdasarkan fare
df_fare = df.groupby('sex')['fare'].mean()
df_fare
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
df_fare.plot()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
df1=df.groupby('who')['age'].sum().to_frame().reset_index()

# Membuat grafik bar
plt.barh(df1['who'],df1['age'],color = ['#B0E0E6','#F0F8FF','#E6E6FA']) 

# Menambahkan Informasi
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title') 

#Tampilkan Plot
plt.show()

# %%
sns.set_context("paper", font_scale=3, rc={"font.size":8,"axes.labelsize":5})
# Construct iris plot
sns.swarmplot(x="who", y="age", data=df1)

# Show plot
plt.show()

# %%
#Tentukan kolom chart
sns.barplot(x = 'who',y = 'age',data = df,palette = "terrain")
#membuat Legend
plt.title('Chart dari gender berdasarkan umur\n')
plt.xlabel('who')
plt.ylabel('age') 
# Tampilkan chart
plt.show()
