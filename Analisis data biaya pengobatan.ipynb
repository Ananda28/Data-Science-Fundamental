# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#Untuk mengarahkan ke gambar statis plot
# %matplotlib inline 
import random

# %%
df = pd.read_csv ('insurance.csv') # load data
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.values
# Out:
# array([[19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [18, 'male', 33.77, ..., 'no', 'southeast', 1725.5523],
#        [28, 'male', 33.0, ..., 'no', 'southeast', 4449.462],
#        ...,
#        [18, 'female', 36.85, ..., 'no', 'southeast', 1629.8335],
#        [21, 'female', 25.8, ..., 'no', 'southwest', 2007.945],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603]],
#       dtype=object)

# %%
df['age']
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
umur = df['age']

# %%
umur.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
umur[ umur > 20]
# Out:
# 2       28
# 3       33
# 4       32
# 5       31
# 6       46
#         ..
# 1331    23
# 1332    52
# 1333    50
# 1336    21
# 1337    61
# Name: age, Length: 1172, dtype: int64

# %%
df['bmi'].max()
# Out:
# 53.13

# %%
df[['sex','region']]
# Out:
#          sex     region
# 0     female  southwest
# 1       male  southeast
# 2       male  southeast
# 3       male  northwest
# 4       male  northwest
# ...      ...        ...
# 1333    male  northwest
# 1334  female  northeast
# 1335  female  southeast
# 1336  female  southwest
# 1337  female  northwest
#
# [1338 rows x 2 columns]

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#filtering
df['children'] > 1
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1333     True
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Name: children, Length: 1338, dtype: bool

# %%
df.groupby('sex')['bmi'].mean()
# Out:
# sex
# female    30.377749
# male      30.943129
# Name: bmi, dtype: float64

# %%
df.groupby('sex')['children'].sum()
# Out:
# sex
# female    711
# male      754
# Name: children, dtype: int64

# %%
df.groupby('children').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='children'>

# %%
# Plot Line
sns.barplot(x = 'region',
            y = 'children',
            data = df)
 
# Show the plot
plt.show()

# %%
# Plot Bar
sns.catplot(x="region", y="age", hue = "children", kind = "bar", data=df)

# %%
# Plot Scatter
sns.relplot(x="age", y="bmi", data = df)

# %%
# Box
sns.catplot(x="children", y="age", kind = "box", data=df)

# %%
# Pointplot 
sns.catplot(x="region", y="age", hue = "children", kind = "point", data=df)

# %%
# Histogram
sns.distplot(df.bmi)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(df.bmi, kde=False, rug = True)
# Out:
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\envs\dsf\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi'>

# %%
# Hexplot 
sns.jointplot(x=df.age, y=df.children, kind="hex", data = df)

# %%
sns.jointplot(x=df.age, y=df.children, kind="kde", data = df)

# %%
#Heatmaps
corrmat = df.corr()
f, ax = plt.subplots(figsize=(9, 7))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %%
# Boxen Plot
sns.catplot(x="age", y="children", data=df, kind="boxen",height=4, aspect=2.7, hue = "region")

# %% [markdown]
# ### SIMPLE LINEAR REGRESSION

# %%
x = df['age']
y = df['bmi']

# %%
sns.set()
plt.axis([15, 68, 0, 60])
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.xlabel('age', fontsize= 15)
plt.ylabel('bmi', fontsize= 15)
plt.plot(x, y, 'go')

# %%
w = 1
x1 = 0
x2 = 60
y1 = x1 * w
y2 = x2 * w

# %%
sns.set()
plt.axis([15, 68, 0, 60])
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.xlabel('age', fontsize= 15)
plt.ylabel('bmi', fontsize= 15)
plt.plot(x, y, 'go')
plt.plot([x1,x2], [y1,y2], 'r')
plt.show()

# %%
def predict(x, w):
    return x * w

# %%
def loss(x, y, w):
    return np.average((predict(x, w)-y) ** 2)

# %%
def train(x, y, iterations, lr):
    w = 0
    for i in range(iterations):
        current_loss = loss(x, y, w)
        print('Iterasi %4d -> Loss: %.6f' % (i, current_loss))
        
        if loss(x, y , w + lr) < current_loss:
            w += lr
        elif loss(x, y , w - lr) < current_loss:
            w -= lr
        else:
            return w
    raise Exception('Terjadi kesalahan pada iterasi ke %d' % iterations)

# %%
w = train(
    x,
    y,
    iterations= 10000,
    lr= 0.01
)
# Out:
# Iterasi    0 -> Loss: 977.403997
# Iterasi    1 -> Loss: 953.345923
# Iterasi    2 -> Loss: 929.634738
# Iterasi    3 -> Loss: 906.270442
# Iterasi    4 -> Loss: 883.253035
# Iterasi    5 -> Loss: 860.582517
# Iterasi    6 -> Loss: 838.258888
# Iterasi    7 -> Loss: 816.282147
# Iterasi    8 -> Loss: 794.652296
# Iterasi    9 -> Loss: 773.369334
# Iterasi   10 -> Loss: 752.433260
# Iterasi   11 -> Loss: 731.844076
# Iterasi   12 -> Loss: 711.601780
# Iterasi   13 -> Loss: 691.706373
# Iterasi   14 -> Loss: 672.157856
# Iterasi   15 -> Loss: 652.956227
# Iterasi   16 -> Loss: 634.101487
# Iterasi   17 -> Loss: 615.593636
# Iterasi   18 -> Loss: 597.432674
# Iterasi   19 -> Loss: 579.618601
# Iterasi   20 -> Loss: 562.151417
# Iterasi   21 -> Loss: 545.031122
# Iterasi   22 -> Loss: 528.257716
# Iterasi   23 -> Loss: 511.831198
# Iterasi   24 -> Loss: 495.751570
# Iterasi   25 -> Loss: 480.018831
# Iterasi   26 -> Loss: 464.632980
# Iterasi   27 -> Loss: 449.594019
# ...

# %%
print('w %.3f' % w)
# Out:
# w 0.700

# %%
age = 80
print('Prediksi: bila umur = %d, maka bminya = %.2f' %(age, predict(age, w)))
# Out:
# Prediksi: bila umur = 80, maka bminya = 56.00
